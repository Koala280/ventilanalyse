# %%
import os
os.listdir("./audios/" + "negative")
# Out:
# ['rec1.wav',
#  'rec10.wav',
#  'rec11.wav',
#  'rec12.wav',
#  'rec13.wav',
#  'rec14.wav',
#  'rec15.wav',
#  'rec16.wav',
#  'rec17.wav',
#  'rec18.wav',
#  'rec19.wav',
#  'rec2.wav',
#  'rec20.wav',
#  'rec200.wav',
#  'rec21.wav',
#  'rec22.wav',
#  'rec23.wav',
#  'rec24.wav',
#  'rec25.wav',
#  'rec26.wav',
#  'rec27.wav',
#  'rec28.wav',
#  'rec29.wav',
#  'rec3.wav',
#  'rec30.wav',
#  'rec31.wav',
#  'rec32.wav',
#  'rec33.wav',
#  'rec34.wav',
#  'rec35.wav',
#  'rec36.wav',
#  'rec37.wav',
#  'rec38.wav',
#  'rec39.wav',
#  'rec4.wav',
#  'rec40.wav',
#  'rec41.wav',
#  'rec42.wav',
#  'rec43.wav',
#  'rec44.wav',
#  'rec45.wav',
#  'rec46.wav',
#  'rec47.wav',
#  'rec48.wav',
#  'rec49.wav',
#  'rec5.wav',
#  'rec50.wav',
#  'rec51.wav',
#  'rec52.wav',
#  'rec53.wav',
#  'rec54.wav',
#  'rec6.wav',
#  'rec67.wav',
#  'rec68.wav',
#  'rec69.wav',
#  'rec7.wav',
#  'rec70.wav',
#  'rec71.wav',
#  'rec72.wav',
#  'rec73.wav',
#  'rec74.wav',
#  'rec75.wav',
# ...
